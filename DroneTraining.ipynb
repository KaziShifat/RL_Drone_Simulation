# %% [markdown]
# Dependency Installation

# %%
# !pip install stable-baselines3 tensorboard gym pygame
# Out:
# Requirement already satisfied: stable-baselines3 in ./rl_py310/lib/python3.10/site-packages (1.8.0)
# Requirement already satisfied: tensorboard in ./rl_py310/lib/python3.10/site-packages (2.20.0)
# Requirement already satisfied: gym in ./rl_py310/lib/python3.10/site-packages (0.21.0)
# Requirement already satisfied: pygame in ./rl_py310/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: matplotlib in ./rl_py310/lib/python3.10/site-packages (from stable-baselines3) (3.10.7)
# Requirement already satisfied: numpy in ./rl_py310/lib/python3.10/site-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: importlib-metadata~=4.13 in ./rl_py310/lib/python3.10/site-packages (from stable-baselines3) (4.13.0)
# Requirement already satisfied: cloudpickle in ./rl_py310/lib/python3.10/site-packages (from stable-baselines3) (3.1.2)
# Requirement already satisfied: torch>=1.11 in ./rl_py310/lib/python3.10/site-packages (from stable-baselines3) (2.9.1)
# Requirement already satisfied: pandas in ./rl_py310/lib/python3.10/site-packages (from stable-baselines3) (2.3.3)
# Requirement already satisfied: packaging in ./rl_py310/lib/python3.10/site-packages (from tensorboard) (25.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./rl_py310/lib/python3.10/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: grpcio>=1.48.2 in ./rl_py310/lib/python3.10/site-packages (from tensorboard) (1.76.0)
# Requirement already satisfied: setuptools>=41.0.0 in ./rl_py310/lib/python3.10/site-packages (from tensorboard) (59.5.0)
# Requirement already satisfied: pillow in ./rl_py310/lib/python3.10/site-packages (from tensorboard) (12.0.0)
# Requirement already satisfied: markdown>=2.6.8 in ./rl_py310/lib/python3.10/site-packages (from tensorboard) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in ./rl_py310/lib/python3.10/site-packages (from tensorboard) (6.33.2)
# Requirement already satisfied: absl-py>=0.4 in ./rl_py310/lib/python3.10/site-packages (from tensorboard) (2.3.1)
# Requirement already satisfied: werkzeug>=1.0.1 in ./rl_py310/lib/python3.10/site-packages (from tensorboard) (3.1.4)
# Requirement already satisfied: typing-extensions~=4.12 in ./rl_py310/lib/python3.10/site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: zipp>=0.5 in ./rl_py310/lib/python3.10/site-packages (from importlib-metadata~=4.13->stable-baselines3) (3.23.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (12.8.93)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (11.3.3.83)
# Requirement already satisfied: jinja2 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (3.1.6)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (0.7.1)
# Requirement already satisfied: filelock in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (3.20.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (12.8.90)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (10.3.9.90)
# Requirement already satisfied: sympy>=1.13.3 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (1.14.0)
# Requirement already satisfied: triton==3.5.1 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (3.5.1)
# Requirement already satisfied: fsspec>=0.8.5 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (2025.12.0)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (12.8.93)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (12.5.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (1.13.1.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (2.27.5)
# Requirement already satisfied: networkx>=2.5.1 in ./rl_py310/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3) (3.4.2)
# Requirement already satisfied: markupsafe>=2.1.1 in ./rl_py310/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Requirement already satisfied: pyparsing>=3 in ./rl_py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./rl_py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: cycler>=0.10 in ./rl_py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./rl_py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./rl_py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in ./rl_py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (4.61.0)
# Requirement already satisfied: pytz>=2020.1 in ./rl_py310/lib/python3.10/site-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./rl_py310/lib/python3.10/site-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in ./rl_py310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./rl_py310/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11->stable-baselines3) (1.3.0)
#
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Environment Loading

# %%
import importlib
import env
importlib.reload(env)

from env import droneEnv
env = droneEnv(render_mode="none")
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.19)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Setting up the Stable-Baseline for training both A2C and DQN

# %%
from stable_baselines3.common.monitor import Monitor

logdir = "./logs/a2c"
env = Monitor(droneEnv(render_mode="none"), logdir)

# %% [markdown]
# A2C Training

# %%
from stable_baselines3 import A2C

model_a2c = A2C(
    "MlpPolicy",
    env,
    learning_rate=3e-4,
    gamma=0.99,
    tensorboard_log="./DroneLog"
)

model_a2c.learn(total_timesteps=300_000)
model_a2c.save("A2C_drone")

# %%
from stable_baselines3 import A2C
from env import droneEnv

env = droneEnv(render_mode="human")
model_a2c = A2C.load("A2C_drone", env=env)

# %%
obs, info = env.reset()
terminated = False
truncated = False

while not (terminated or truncated):
    action, _ = model_a2c.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    env.render()

env.close()

# %% [markdown]
# A2C Demo Video Generation

# %%
import imageio
import numpy as np
from stable_baselines3 import A2C
from env import droneEnv


env = droneEnv(render_mode="rgb_array")  # important for video recording

model = A2C.load("A2C_drone", env=env)

video_path = "a2c_drone_demo.mp4"
fps = 30
writer = imageio.get_writer(video_path, fps=fps)

obs, _ = env.reset()
done = False
truncated = False

while not (done or truncated):
    # Predict action
    action, _ = model.predict(obs, deterministic=True)
    
    # Step environment
    obs, reward, done, truncated, info = env.step(action)

    # Capture frame
    frame = env.render()  # returns RGB frame when rgb_array mode is used
    writer.append_data(frame)

writer.close()
env.close()

print(f"Video saved at: {video_path}")

# %% [markdown]
# DQN Training

# %%
from stable_baselines3 import DQN

model_dqn = DQN(
    "MlpPolicy",
    env,
    learning_rate=3e-4,
    gamma=0.99,
    buffer_size=100_000,      # Replay buffer size
    batch_size=64,            # Mini-batch size
    learning_starts=1_000,    # Start learning after some experience
    target_update_interval=500, # How often to update target network
    exploration_initial_eps=1.0,
    exploration_final_eps=0.05,
    exploration_fraction=0.3,
    tensorboard_log="./DroneLog"
)

model_dqn.learn(total_timesteps=300_000)
model_dqn.save("DQN_drone")

# %%
from stable_baselines3 import DQN
from env import droneEnv

# Create environment (same settings used during training)
env = droneEnv(render_mode="human")

# Load the trained DQN model
model_dqn = DQN.load("DQN_drone", env=env)

# Run a single episode
obs, _ = env.reset()
done = False

while not done:
    action, _ = model_dqn.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env.step(action)
    env.render()

env.close()

# %% [markdown]
# DQN Video Demo

# %%
env = droneEnv(render_mode="rgb_array")  

# Load trained DQN model
model = DQN.load("DQN_drone", env=env)

video_path = "dqn_drone_demo.mp4"
fps = 30
writer = imageio.get_writer(video_path, fps=fps)

obs, _ = env.reset()
done = False
truncated = False

while not (done or truncated):
    # Predict action
    action, _ = model.predict(obs, deterministic=True)
    
    # Step environment
    obs, reward, done, truncated, info = env.step(action)

    # Capture frame
    frame = env.render()  # returns RGB frame when rgb_array mode is used
    writer.append_data(frame)

writer.close()
env.close()

print(f"Video saved at: {video_path}")

# %% [markdown]
# Data Monitoring through TensorBoard

# %%
# %load_ext tensorboard
# %tensorboard --logdir DroneLog
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 20521), started 0:56:49 ago. (Use '!kill 20521' to kill it.)
#       <iframe id="tensorboard-frame-24fd27a9afadfb5c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-24fd27a9afadfb5c");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
